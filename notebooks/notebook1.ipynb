# %% [markdown]
# initial notebook -- organization and data prep

# %% [markdown]
# mostly for messing around and testing

# %%
import pandas as pd
import numpy as np
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import torch
import tensorflow

pd.set_option('display.max_columns', None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 import sklearn
#       8 import torch
# ----> 9 import tensorflow
#      11 pd.set_option('display.max_columns', None)
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
df = pd.read_csv("../data/matchups-2007.csv")
print(df.head())  # View first few rows
print(df.info())  # Check data types & missing values
# Out:
#            game  season home_team away_team  starting_min  end_min  \
# 0  200610310LAL    2007       LAL       PHO             0        5
# 1  200610310LAL    2007       LAL       PHO             6        7
# 2  200610310LAL    2007       LAL       PHO             8        9
# 3  200610310LAL    2007       LAL       PHO            10       10
# 4  200610310LAL    2007       LAL       PHO            11       11
#
#          home_0         home_1         home_2         home_3  ... pf_visitor  \
# 0  Andrew Bynum     Lamar Odom    Luke Walton  Sasha Vujacic  ...          0
# 1  Andrew Bynum     Lamar Odom    Luke Walton  Sasha Vujacic  ...          0
# 2    Lamar Odom    Luke Walton  Maurice Evans   Ronny Turiaf  ...          0
# 3    Lamar Odom    Luke Walton  Maurice Evans   Ronny Turiaf  ...          0
# 4   Luke Walton  Maurice Evans   Ronny Turiaf   Smush Parker  ...          1
#
#   reb_visitor dreb_visitor oreb_visitor to_visitor pts_visitor  pct_visitor  \
# ...

# %%
df.head()
# Out:
#            game  season home_team away_team  starting_min  end_min  \
# 0  200610310LAL    2007       LAL       PHO             0        5
# 1  200610310LAL    2007       LAL       PHO             6        7
# 2  200610310LAL    2007       LAL       PHO             8        9
# 3  200610310LAL    2007       LAL       PHO            10       10
# 4  200610310LAL    2007       LAL       PHO            11       11
#
#          home_0         home_1         home_2         home_3  \
# 0  Andrew Bynum     Lamar Odom    Luke Walton  Sasha Vujacic
# 1  Andrew Bynum     Lamar Odom    Luke Walton  Sasha Vujacic
# 2    Lamar Odom    Luke Walton  Maurice Evans   Ronny Turiaf
# 3    Lamar Odom    Luke Walton  Maurice Evans   Ronny Turiaf
# 4   Luke Walton  Maurice Evans   Ronny Turiaf   Smush Parker
#
#                 home_4             away_0           away_1       away_2  \
# 0         Smush Parker         Boris Diaw      Kurt Thomas    Raja Bell
# ...
